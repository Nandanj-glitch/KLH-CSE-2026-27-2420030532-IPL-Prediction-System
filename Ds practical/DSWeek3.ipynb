# %%
import numpy as np
from scipy.spatial import distance
pointA = [1,2,9]
pointB = [4,5,7]
euclidean_dist = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dist)
similarity_euclidean = 1 / (1 + euclidean_dist)
print("Euclidean Similarity:", similarity_euclidean)
# Out:
# Euclidean Distance: 4.69041575982343
# Euclidean Similarity: 0.1757340838011157

# %%
from scipy.spatial import distance as dist
pointA = [1,3,6]
pointB = [4,2,7]
manhattan_dist = dist.cityblock(pointA, pointB)
print("Manhattan Distance:", manhattan_dist)
#Similarity(inverse of distance)
similarity_manhattan = 1 / (1 + manhattan_dist)
print("Manhattan Similarity:", similarity_manhattan)
# Out:
# Manhattan Distance: 5
# Manhattan Similarity: 0.16666666666666666

# %%
from scipy.spatial import distance as dist
pointA = [1,7,3]
pointB = [4,2,3]
minkowski_distance_p3 = dist.minkowski(pointA, pointB, p=3)
print("Minkowski Distance(p=3):", minkowski_distance_p3)

similarity_minkowski = 1 / (1 + minkowski_distance_p3)
print("Minkowski Similarity(p=3):", similarity_minkowski)
# Out:
# Minkowski Distance(p=3): 5.336803297443889
# Minkowski Similarity(p=3): 0.15780827541283718

# %%
import pandas as pd
#Example dataset
df = pd.DataFrame({
    'X': [10,20,30,40,50],
    'Y': [12,24,36,47,59]
})
#Pearson correlation
corr_matrix = df.corr(method = 'pearson')
print("Pearson Correlatin Matrix:\n",corr_matrix)
# Out:
# Pearson Correlatin Matrix:
#           X        Y
# X  1.00000  0.99989
# Y  0.99989  1.00000

# %%
import pandas as pd
#Example dataset
df = pd.DataFrame({
    'X': [1,2,3,4,5],
    'Y': [1,2,3,4,5]
})
#Pearson correlation
corr_matrix = df.corr(method = 'pearson')
print("Pearson Correlatin Matrix:\n",corr_matrix)
# Out:
# Pearson Correlatin Matrix:
#       X    Y
# X  1.0  1.0
# Y  1.0  1.0

# %%
import pandas as pd
df = pd.read_csv('Iris.csv')
print(df.corr(method='pearson',numeric_only=float))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import pandas as pd
from scipy.stats import spearmanr
#Example dataset
df = pd.DataFrame({
    'X': [10,20,30,40,50],
    'Y': [12,24,36,47,59]
})
#Spearman correlation
corr_value, p_value = spearmanr(df['X'], df['Y'])
print(f"Spearman Coorrelation Coefficient: {corr_value}")
print(f"P-value: {p_value}")
# Out:
# Spearman Coorrelation Coefficient: 0.9999999999999999
# P-value: 1.4042654220543672e-24

# %%
#for datset:
import pandas as pd
df = pd.read_csv('Iris.csv')
print(df.corr(method='spearman',numeric_only=float))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.734054     -0.411539       0.868498
# SepalLengthCm  0.734054       1.000000     -0.159457       0.881386
# SepalWidthCm  -0.411539      -0.159457      1.000000      -0.303421
# PetalLengthCm  0.868498       0.881386     -0.303421       1.000000
# PetalWidthCm   0.879045       0.834421     -0.277511       0.936003
#
#                PetalWidthCm
# Id                 0.879045
# SepalLengthCm      0.834421
# SepalWidthCm      -0.277511
# PetalLengthCm      0.936003
# PetalWidthCm       1.000000

# %%
import pandas as pd
#Example dataset
df = pd.DataFrame({
    'student_name': ['Crow','Blu','Mathew','Githa','Ram'],
    'Qc': [12,24,36,47,59],
    'Ds': [34,54,26,37,59],
    'Adas': [42,24,36,47,59],
    'Toc': [52,34,56,17,59],
    'Maths': [12,44,39,37,59],
})
#Pearson correlation
corr_matrix = df.corr(method = 'pearson', numeric_only=float)
print("Pearson Correlatin Matrix:\n",corr_matrix)
# Out:
# Pearson Correlatin Matrix:
#               Qc        Ds      Adas       Toc     Maths
# Qc     1.000000  0.372056  0.688696 -0.018872  0.814672
# Ds     0.372056  1.000000  0.198976  0.014133  0.660437
# Adas   0.688696  0.198976  1.000000  0.246572  0.270384
# Toc   -0.018872  0.014133  0.246572  1.000000  0.071593
# Maths  0.814672  0.660437  0.270384  0.071593  1.000000

# %%
import pandas as pd
#Example dataset
df = pd.DataFrame({
    'student_name': ['Crow','Blu','Mathew','Githa','Ram'],
    'Qc': [12,24,36,47,59],
    'Ds': [34,54,26,37,59],
    'Adas': [42,24,36,47,59],
    'Toc': [52,34,56,17,59],
    'Maths': [12,44,39,37,59],
})
#Pearson correlation
corr_matrix = df.corr(method = 'spearman', numeric_only=True)
print("Spearman Correlatin Matrix:\n",corr_matrix)
# Out:
# Spearman Correlatin Matrix:
#          Qc   Ds  Adas  Toc  Maths
# Qc     1.0  0.5   0.7  0.3    0.6
# Ds     0.5  1.0   0.4  0.1    0.7
# Adas   0.7  0.4   1.0  0.3    0.1
# Toc    0.3  0.1   0.3  1.0    0.5
# Maths  0.6  0.7   0.1  0.5    1.0

# %%
def hamming_distance(str1,str2):
  if len(str1) != len(str2):
    raise ValueError("Strings must be of equal length")
  return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))

s1 = "karolin"
s2="kathrin"
dist = hamming_distance(s1, s2)
print(f"Hamming Distance between '{s1}' and '{s2}' : {dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin' : 3

# %%
def hamming_distance(str1,str2):
  if len(str1) != len(str2):
    raise ValueError("Strings must br of equal length")
  return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))

s1 ="The dragon lives forever"
s2 ="The god dies but comes b"
dist = hamming_distance(s1, s2)
print(f"Hamming Distance between '{s1}' and '{s2}' : {dist}")
# Out:
# Hamming Distance between 'The dragon lives forever' and 'The god dies but comes b' : 17

# %%
def jaccard_index(str1,str2):
  set1, set2 = set(str1.split()), set(str2.split())
  intersection = set1.intersection(set2)
  union = set1.union(set2)
  return len(intersection) / len(union)
  #Example usage
s1 = "data science is fun"
s2 = "science makes data useful"

print("Jaccard Index:", jaccard_index(s1, s2))
# Out:
# Jaccard Index: 0.3333333333333333

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Example sentences
s1 = "data science is fun"
s2 = "science makes data useful"
# Cnvert text to vector representation
vectorizer = CountVectorizer().fit([s1,s2])
vectors = vectorizer.transform([s1,s2])
#Compute cosine similarity
cos_sim = cosine_similarity(vectors[0], vectors[1])[0][0]
print("Cosine Similarity:", cos_sim)
# Out:
# Cosine Similarity: 0.5

# %%
def lcs_length(X, Y):
  m,n = len(X), len(Y)
  dp = [[0] * (n + 1) for _ in range(m + 1)]
  for i in range(m):
    for j in range(n):
      if X[i] == Y[j]:
        dp[i + 1][j + 1] = dp[i][j] + 1
      else:
        dp[i + 1][j + 1] = max(dp[i][j+1], dp[i + 1][j])
  return dp[m][n]
seq1 = "ABCDEF"
seq2 = "AEBDF"
length = lcs_length(seq1, seq2)
print(f"Longest Common Subsequence length between '{seq1}' and '{seq2}': {length}")
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'AEBDF': 4
